# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_csv("kidney_disease.csv")

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (400, 26)

# %%
data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
data.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
data.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data['age']=data['age'].fillna(data['age'].mean())

# %%
data['bp']=data['bp'].fillna(data['bp'].mean())

# %%
data['sg']=data['sg'].fillna(data['sg'].mean())

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# id                  0
# age                 0
# bp                  0
# sg                  0
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['al'].unique()
# Out:
# array([ 1.,  4.,  2.,  3.,  0., nan,  5.])

# %%
data
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imp_mode=SimpleImputer(missing_values=np.nan,strategy="most_frequent")

# %%
df_imputed=pd.DataFrame(imp_mode.fit_transform(data))

# %%
sns.heatmap(df_imputed.isnull())
# Out:
# <Axes: >

# %%
df_imputed.columns=data.columns

# %%
df_imputed.isnull().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
df_imputed.describe()
# Out:
#          id    age     bp      sg     al     su     rbc      pc         pcc  \
# count   400  400.0  400.0  400.00  400.0  400.0     400     400         400
# unique  400   77.0   11.0    6.00    6.0    6.0       2       2           2
# top       0   60.0   80.0    1.02    0.0    0.0  normal  normal  notpresent
# freq      1   19.0  116.0  106.00  245.0  339.0     353     324         358
#
#                 ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# count          400  ...  400   400  400  400  400  400   400  400  400
# unique           2  ...   44    92   49    2    5    3     2    2    2
# top     notpresent  ...   41  9800  5.2   no   no   no  good   no   no
# freq           378  ...   91   116  148  253  260  364   318  324  340
#
#        classification
# count             400
# unique              3
# top               ckd
# freq              248
#
# [4 rows x 26 columns]

# %%
df_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    object
#  1   age             400 non-null    object
#  2   bp              400 non-null    object
#  3   sg              400 non-null    object
#  4   al              400 non-null    object
#  5   su              400 non-null    object
#  6   rbc             400 non-null    object
#  7   pc              400 non-null    object
#  8   pcc             400 non-null    object
#  9   ba              400 non-null    object
#  10  bgr             400 non-null    object
#  11  bu              400 non-null    object
#  12  sc              400 non-null    object
#  13  sod             400 non-null    object
#  14  pot             400 non-null    object
#  15  hemo            400 non-null    object
#  16  pcv             400 non-null    object
# ...

# %%
df_imputed['id']
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 395    395
# 396    396
# 397    397
# 398    398
# 399    399
# Name: id, Length: 400, dtype: object

# %%
df_imputed=df_imputed.drop('id',axis=1)

# %%
df_imputed['age'] = df_imputed['age'].astype(str).replace('51.48337595907928', '52.0').astype(float)
df_imputed['bp'] = df_imputed['bp'].astype(str).replace('76.46907216494846', '76.0').astype(float)
df_imputed['sg'] = df_imputed['sg'].astype(str).replace('1.0174079320113314', '1.017').astype(float)
df_imputed['pcv'] = df_imputed['pcv'].astype(str).replace('\t43', '43')
df_imputed['pcv'] = df_imputed['pcv'].astype(str).replace('\t?', '91')
df_imputed['wc'] = df_imputed['wc'].astype(str).replace('\t8400', '8400')
df_imputed['wc'] = df_imputed['wc'].astype(str).replace('\t?', '9800')
df_imputed['rc'] = df_imputed['rc'].astype(str).replace('\t?', '5.8')
df_imputed['dm'] = df_imputed['dm'].astype(str).replace('\tno', 'no')
df_imputed['dm'] = df_imputed['dm'].astype(str).replace('\tyes', 'yes')
df_imputed['dm'] = df_imputed['dm'].astype(str).replace(' yes', 'yes')
df_imputed['cad']=df_imputed['cad'].astype(str).replace('\tno','no')
df_imputed['classification']=df_imputed['classification'].astype(str).replace('ckd\t','ckd')

# %%
df_imputed.head()
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr  ... pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0  121.0  ...  44  7800  5.2  yes  yes  no  good   no   no            ckd
# 1   99.0  ...  38  6000  5.2   no   no  no  good   no   no            ckd
# 2  423.0  ...  31  7500  5.2   no  yes  no  poor   no  yes            ckd
# 3  117.0  ...  32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# 4  106.0  ...  35  7300  4.6   no   no  no  good   no   no            ckd
#
# [5 rows x 25 columns]

# %%
df_imputed['rbc'] = df_imputed['rbc'].map({'normal': 1, 'abnormal': 0})
df_imputed['pc'] = df_imputed['pc'].map({'normal': 1, 'abnormal': 0})
df_imputed['pcc'] = df_imputed['pcc'].map({'present': 1, 'notpresent': 0})
df_imputed['ba'] = df_imputed['ba'].map({'present': 1, 'notpresent': 0})
df_imputed['htn'] = df_imputed['htn'].map({'yes': 1, 'no': 0})
df_imputed['dm'] = df_imputed['dm'].map({'yes': 1, 'no': 0})
df_imputed['cad'] = df_imputed['cad'].map({'yes': 1, 'no': 0})
df_imputed['appet'] = df_imputed['appet'].map({'good': 1, 'poor': 0})
df_imputed['pe'] = df_imputed['pe'].map({'yes': 1, 'no': 0})
df_imputed['ane'] = df_imputed['ane'].map({'yes': 1, 'no': 0})
df_imputed['classification'] = df_imputed['classification'].map({'ckd': 1, 'notckd': 0})

# %%
df_imputed['rbc']=df_imputed['rbc'].astype(int)
df_imputed['pc']=df_imputed['pc'].astype(int)
df_imputed['pcc']=df_imputed['pcc'].astype(int)
df_imputed['ba']=df_imputed['ba'].astype(int)
df_imputed['bgr']=df_imputed['bgr'].astype(float)
df_imputed['bu']=df_imputed['bu'].astype(float)
df_imputed['sc']=df_imputed['sc'].astype(float)
df_imputed['sod']=df_imputed['sod'].astype(float)
df_imputed['pot']=df_imputed['pot'].astype(float)
df_imputed['hemo']=df_imputed['hemo'].astype(float)
df_imputed['htn']=df_imputed['htn'].astype(int)
df_imputed['age']=df_imputed['age'].astype(int)
df_imputed['bp']=df_imputed['bp'].astype(int)
df_imputed['sg']=df_imputed['sg'].astype(float)
df_imputed['al']=df_imputed['al'].astype(int)
df_imputed['su']=df_imputed['su'].astype(int)
df_imputed['pcv']=df_imputed['pcv'].astype(int)
df_imputed['wc']=df_imputed['wc'].astype(int)
df_imputed['rc']=df_imputed['rc'].astype(float)
df_imputed['classification']=df_imputed['classification'].astype(int)

# %%
df_imputed.head()
# Out:
#    age  bp     sg  al  su  rbc  pc  pcc  ba    bgr  ...  pcv    wc   rc  htn  \
# 0   48  80  1.020   1   0    1   1    0   0  121.0  ...   44  7800  5.2    1
# 1    7  50  1.020   4   0    1   1    0   0   99.0  ...   38  6000  5.2    0
# 2   62  80  1.010   2   3    1   1    0   0  423.0  ...   31  7500  5.2    0
# 3   48  70  1.005   4   0    1   0    1   0  117.0  ...   32  6700  3.9    1
# 4   51  80  1.010   2   0    1   1    0   0  106.0  ...   35  7300  4.6    0
#
#    dm  cad  appet  pe  ane  classification
# 0   1    0      1   0    0             ckd
# 1   0    0      1   0    0             ckd
# 2   1    0      0   0    1             ckd
# 3   0    0      0   1    1             ckd
# 4   0    0      1   0    0             ckd
#
# [5 rows x 25 columns]

# %%
df_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    int32
#  1   bp              400 non-null    int32
#  2   sg              400 non-null    float64
#  3   al              400 non-null    int32
#  4   su              400 non-null    int32
#  5   rbc             400 non-null    int32
#  6   pc              400 non-null    int32
#  7   pcc             400 non-null    int32
#  8   ba              400 non-null    int32
#  9   bgr             400 non-null    float64
#  10  bu              400 non-null    float64
#  11  sc              400 non-null    float64
#  12  sod             400 non-null    float64
#  13  pot             400 non-null    float64
#  14  hemo            400 non-null    float64
#  15  pcv             400 non-null    int32
#  16  wc              400 non-null    int32
# ...

# %%
df_imputed['classification'].unique()
# Out:
# array([1, 0])

# %%
numeric_columns = df_imputed.select_dtypes(include=['float64', 'float32', 'int64', 'int32']).columns
corr1 = df_imputed[numeric_columns].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr1, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %%
X=df_imputed.drop(columns='classification',axis=1)
Y=df_imputed['classification']

# %%
X.shape
# Out:
# (400, 24)

# %%
Y.shape
# Out:
# (400,)

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: classification, Length: 400, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,stratify=Y,random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
models={
    "SVC":SVC(kernel='linear'),
    "Random Forest ":RandomForestClassifier(n_estimators=100,random_state=10,max_depth=6),
    "Gradient boosting ":GradientBoostingClassifier(n_estimators=100),
    " Kneighbors ":KNeighborsClassifier(n_neighbors=10),
     "Ada Boost":AdaBoostClassifier(n_estimators=100),
     "Logistic Regression":LogisticRegression(penalty='l2', C=1.0, random_state=10)

}

# %%
for model_name, model in models.items():
    print(f"\nEvaluating {model_name}...\n")

    model.fit(X_train, Y_train)
    train_predictions = model.predict(X_train)
    train_accuracy = accuracy_score(Y_train, train_predictions)
    test_predictions = model.predict(X_test)
    test_accuracy = accuracy_score(Y_test, test_predictions)

    cm = confusion_matrix(Y_test, test_predictions)
    
    print(f"{model_name} accuracy on test set: {test_accuracy:.4f}")
    print(f"{model_name} accuracy on train set: {train_accuracy:.4f}")
    print("Confusion matrix:")
    print(np.array2string(cm, separator=', '))
# Out:
# Evaluating SVC...
#
# SVC accuracy on test set: 0.9750
# SVC accuracy on train set: 0.9722
# Confusion matrix:
# [[15,  0],
#  [ 1, 24]]
#
# Evaluating Random Forest ...
#
# Random Forest  accuracy on test set: 1.0000
# Random Forest  accuracy on train set: 1.0000
# Confusion matrix:
# [[15,  0],
#  [ 0, 25]]
#
# Evaluating Gradient boosting ...
#
# Gradient boosting  accuracy on test set: 1.0000
# Gradient boosting  accuracy on train set: 1.0000
# Confusion matrix:
# [[15,  0],
#  [ 0, 25]]
#
# Evaluating  Kneighbors ...
#
#  Kneighbors  accuracy on test set: 0.7500
#  Kneighbors  accuracy on train set: 0.7528
# Confusion matrix:
# [[13,  2],
#  [ 8, 17]]
#
# Evaluating Ada Boost...
#
# Ada Boost accuracy on test set: 1.0000
# Ada Boost accuracy on train set: 1.0000
# Confusion matrix:
# [[15,  0],
#  [ 0, 25]]
#
# Evaluating Logistic Regression...
#
# Logistic Regression accuracy on test set: 0.9000
# Logistic Regression accuracy on train set: 0.8889
# Confusion matrix:
# ...

# %%
from sklearn.model_selection import cross_val_score
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=10)
# Perform 5-fold cross-validation
cv_scores = cross_val_score(model, X, Y, cv=5)
print("Cross-validation scores:", cv_scores)
print("Mean cross-validation score:", cv_scores.mean())
# Out:
# Cross-validation scores: [1.     1.     1.     0.9875 1.    ]
# Mean cross-validation score: 0.9974999999999999

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
import tensorflow as tf
from tf.keras.models import Sequential
from tf.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_data=(X_test, Y_test))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 import tensorflow as tf
#       2 import distutils as _distutils
#       3 from tf.keras.models import Sequential
#
# File c:\Users\kushr\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
#      28 # pylint: disable=g-bad-import-order,protected-access,g-import-not-at-top
# ---> 30 import distutils as _distutils
#      31 import importlib
#      32 import inspect as _inspect
#
# ...
